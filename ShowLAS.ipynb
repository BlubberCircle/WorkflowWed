# %%
# %matplotlib inline

#Import the welly library
import welly

#Set the well path
file_path = 'Insert Well Path Here.las'

#Create a Well object
well = welly.Well()

#Add curves to that object from the .las file
well.add_curves_from_las(file_path)

#Plot the curves
well.plot(extents = 'curves')
# Out:
# Found nonstandard LAS section: ~Tops
